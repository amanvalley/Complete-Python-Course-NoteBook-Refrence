# %% [markdown]
# # OS Module

# %% [markdown]
# We Already Know how to open an individual file with Python, but we still don't know how to do few things:
#
#     1. what if we have to open every files in a directory?
#     2. what if we want to actually move files around on our computer?
#
# Python's os module and shutil module allow us to easily navigate files and directories on our computer and then
# perform actions on them, like: moving them or deleting them.

# %%
pwd # Special Command in Jupyter notebook to check current working directory.
# Out:
# 'C:\\Users\\91912\\Untitled Folder'

# %%
f = open('os_practice.txt','w+')
f.write('This is a test line')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91912\\Untitled Folder'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Advance Python Modules.ipynb',
#  'Comaprision Operator.ipynb',
#  'Decorators.ipynb',
#  'Dictionaries.ipynb',
#  'Dunder methods.ipynb',
#  'Error And Exceptional Handling.ipynb',
#  'Files.ipynb',
#  'For Loop.ipynb',
#  'Functions.ipynb',
#  'Generator.ipynb',
#  'If Elif else .ipynb',
#  'Inheritance, polymorphism and Abstract Class.ipynb',
#  'Interations of Functions in python.ipynb',
#  'lambda_map_filter.ipynb',
#  'List Comprehension.ipynb',
#  'List.ipynb',
#  'mytxt.txt',
#  'Nested statements and scope.ipynb',
#  'new_file1.txt',
#  'new_text.txt',
#  'Numbers.ipynb',
#  'Object Oriented Programming.ipynb',
#  'OS Modules.ipynb',
#  'os_practice.txt',
#  'os_test.txt',
#  'practice.txt',
#  'Sets and Booleans.ipynb',
#  'strings.ipynb',
#  'testfile',
#  'test_file',
#  'textfile.txt',
#  'Tuple.ipynb',
#  'Untitled.ipynb',
#  'Useful Operators in Python.ipynb',
#  'While Loop.ipynb']

# %%
os.listdir('C:\\Users\\91912')
# Out:
# ['.android',
#  '.AndroidStudio3.5',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.eclipse',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.m2',
#  '.matplotlib',
#  '.nbi',
#  '.oracle',
#  '.python_history',
#  '00-Generative-Adversarial-Networks.ipynb',
#  '01-911 Calls Data Capstone Project.ipynb',
#  '01-Autoencoders-on-Image-Data.ipynb',
#  '01-Choropleth Maps.ipynb',
#  '02-911 Calls Data Capstone Project - Solutions.ipynb',
#  '02-Choropleth Maps Exercise.ipynb',
#  '03-Choropleth Maps Exercise - Solutions.ipynb',
#  '03-Deep-Learning-Custom-Images-Malaria.ipynb',
#  '03-Finance Project.ipynb',
#  '04-Finance Project - Solutions.ipynb',
#  '05-DL-CV-Assessment-Solution.ipynb',
#  '2011_US_AGRI_Exports',
#  '2012_Election_Data',
#  '2014_World_GDP',
#  '2014_World_Power_Consumption',
#  '3D Objects',
#  '911.csv',
#  'Adap_thresh_apple.png',
#  'advertising.csv',
#  'AndroidStudioProjects',
#  'ansel',
#  'AppData',
#  'apple1.jpg',
# ...

# %%
import shutil

# %%
shutil.move('os_practice.txt', 'C:\\Users\\91912')
# Out:
# 'C:\\Users\\91912\\os_practice.txt'

# %%
os.listdir('C:\\Users\\91912')
# Out:
# ['.android',
#  '.AndroidStudio3.5',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.eclipse',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.m2',
#  '.matplotlib',
#  '.nbi',
#  '.oracle',
#  '.python_history',
#  '00-Generative-Adversarial-Networks.ipynb',
#  '01-911 Calls Data Capstone Project.ipynb',
#  '01-Autoencoders-on-Image-Data.ipynb',
#  '01-Choropleth Maps.ipynb',
#  '02-911 Calls Data Capstone Project - Solutions.ipynb',
#  '02-Choropleth Maps Exercise.ipynb',
#  '03-Choropleth Maps Exercise - Solutions.ipynb',
#  '03-Deep-Learning-Custom-Images-Malaria.ipynb',
#  '03-Finance Project.ipynb',
#  '04-Finance Project - Solutions.ipynb',
#  '05-DL-CV-Assessment-Solution.ipynb',
#  '2011_US_AGRI_Exports',
#  '2012_Election_Data',
#  '2014_World_GDP',
#  '2014_World_Power_Consumption',
#  '3D Objects',
#  '911.csv',
#  'Adap_thresh_apple.png',
#  'advertising.csv',
#  'AndroidStudioProjects',
#  'ansel',
#  'AppData',
#  'apple1.jpg',
# ...

# %%
import send2trash

# %%
shutil.move('C:\\Users\\91912\\os_practice.txt',os.getcwd())
# Out:
# 'C:\\Users\\91912\\Untitled Folder\\os_practice.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Advance Python Modules.ipynb',
#  'Comaprision Operator.ipynb',
#  'Decorators.ipynb',
#  'Dictionaries.ipynb',
#  'Dunder methods.ipynb',
#  'Error And Exceptional Handling.ipynb',
#  'Files.ipynb',
#  'For Loop.ipynb',
#  'Functions.ipynb',
#  'Generator.ipynb',
#  'If Elif else .ipynb',
#  'Inheritance, polymorphism and Abstract Class.ipynb',
#  'Interations of Functions in python.ipynb',
#  'lambda_map_filter.ipynb',
#  'List Comprehension.ipynb',
#  'List.ipynb',
#  'mytxt.txt',
#  'Nested statements and scope.ipynb',
#  'new_file1.txt',
#  'new_text.txt',
#  'Numbers.ipynb',
#  'Object Oriented Programming.ipynb',
#  'OS Modules.ipynb',
#  'os_practice.txt',
#  'os_test.txt',
#  'practice.txt',
#  'Sets and Booleans.ipynb',
#  'strings.ipynb',
#  'testfile',
#  'test_file',
#  'textfile.txt',
#  'Tuple.ipynb',
#  'Untitled.ipynb',
#  'Useful Operators in Python.ipynb',
#  'While Loop.ipynb']

# %%
send2trash.send2trash('os_practice.txt')

# %%
filepath = 'C:\\Users\\91912\\Untitled Folder'
for folder, subfolder, files in os.walk(filepath):
    print(f'currently looking at {folder}')
    print('\n')
    print('The sub folders are:')
    
    for folders in subfolder:
        print(f'Subfolder:{folder}')
    print('\n')
    print('the files are:')
    for f in files:
        print(f'File:{f}')
    print('\n')
# Out:
# currently looking at C:\Users\91912\Untitled Folder
#
#
# The sub folders are:
# Subfolder:C:\Users\91912\Untitled Folder
#
#
# the files are:
# File:Advance Python Modules.ipynb
# File:Comaprision Operator.ipynb
# File:Decorators.ipynb
# File:Dictionaries.ipynb
# File:Dunder methods.ipynb
# File:Error And Exceptional Handling.ipynb
# File:Files.ipynb
# File:For Loop.ipynb
# File:Functions.ipynb
# File:Generator.ipynb
# File:If Elif else .ipynb
# File:Inheritance, polymorphism and Abstract Class.ipynb
# File:Interations of Functions in python.ipynb
# File:lambda_map_filter.ipynb
# File:List Comprehension.ipynb
# File:List.ipynb
# File:mytxt.txt
# File:Nested statements and scope.ipynb
# File:new_file1.txt
# File:new_text.txt
# File:Numbers.ipynb
# File:Object Oriented Programming.ipynb
# File:OS Modules.ipynb
# File:os_test.txt
# File:practice.txt
# File:Sets and Booleans.ipynb
# File:strings.ipynb
# File:testfile
# File:test_file
# File:textfile.txt
# File:Tuple.ipynb
# ...
