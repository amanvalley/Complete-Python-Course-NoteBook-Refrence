# %% [markdown]
# # Comparison Operators

# %%
3 == 3
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
4 != 4
# Out:
# False

# %%
5 != 4
# Out:
# True

# %%
2 < 1
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
2 <= 2
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
2 >= 1
# Out:
# True

# %%
2>=2
# Out:
# True

# %% [markdown]
# Chained Comparison Operators

# %%
1 < 3 and 3 < 5
# Out:
# True

# %%
1 < 3 < 5
# Out:
# True

# %%
1 < 3 and 3 < 2
# Out:
# False

# %%
1 == 3 or 2 < 4
# Out:
# True

# %%
1 == 5 or 10 == 1
# Out:
# False

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True
