# %% [markdown]
# # Advanced Sets

# %%
s = set() # Creating an empty set.

# %%
s.add(1) # Adding Elements to the set.

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear() # To Clear all the elements of the set.

# %%
s
# Out:
# set()

# %%
s = {1,2,3}
s_copy = s.copy() # Creating a copy of the defined set.

# %%
s
# Out:
# {1, 2, 3}

# %%
s_copy
# Out:
# {1, 2, 3}

# %%
s.add(4)

# %%
s
# Out:
# {1, 2, 3, 4}

# %%
s_copy
# Out:
# {1, 2, 3}

# %%
s1 = {1,2,3}

s2 = {1,2,4}

# %%
s1.difference(s2)
# Out:
# {3}

# %%
s1 = {1,2,3}
s2 = {1,4,5}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {2, 3}

# %%
s = {1,2,3,4}

# %%
s.discard(2)

# %%
s.discard(3)

# %%
s
# Out:
# {1, 4}

# %%
s1 = {1,2,3}
s2 = {1,2,4}

# %%
s1.intersection(s2)
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1.intersection_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1 = {1,2}
s2 = {1,2,4}
s3 = {5}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.isdisjoint(s3)
# Out:
# True

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.issubset(s2)
# Out:
# True

# %%
s2.issubset(s1)
# Out:
# False

# %%
s2.issuperset(s1)
# Out:
# True

# %%
s1.issuperset(s2)
# Out:
# False

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {1, 2, 4}

# %%
s1.union(s2)
# Out:
# {1, 2, 4}

# %%
s1.update(s2)

# %%
s1
# Out:
# {1, 2, 4}
